# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07  1.077230
# 2019-06-08  1.480017
# 2019-06-09 -2.255951
# 2019-06-10  0.106874
# 2019-06-11 -0.894823

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  1.077230
# 2019-06-08  2.557248
# 2019-06-09  0.301297
# 2019-06-10  0.408171
# 2019-06-11 -0.486652

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.569321
# 2019-06-08   -0.628034
# 2019-06-09   -1.884680
# 2019-06-10   -2.913865
# 2019-06-11   -3.582337
# Freq: D, dtype: float64

# %%
type(df), type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.head()
# Out:
# 2019-06-07   -0.569321
# 2019-06-08   -0.628034
# 2019-06-09   -1.884680
# 2019-06-10   -2.913865
# 2019-06-11   -3.582337
# Freq: D, dtype: float64

# %%
ts.plot()# ts.plot(figsize=(5,5))

# %%
ts.plot(figsize=(5,5)) # index values will be on  X axis and values will be on Y axis

# %%
ts.plot(figsize=(50,50))

# %%
plt.plot(df)

# %%
plt.plot(ts)

# %%
df.plot()

# %%
# loading iris dataset
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis') # Index values 
ax.set_ylabel('Y Axis') # column values
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
ts.plot(kind = 'bar')

# %%
df = iris.drop(['species'], axis = 1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')

# %%
df.iloc[0].plot.bar() # X axis is index data and Y is values

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].plot(kind = 'bar') # X aixs is Index and Y axis is values

# %%
df = pd.DataFrame(randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -1.265344 -0.771304 -0.545632  0.975568
# 1 -1.866019  0.530352  1.165799  0.246659
# 2  1.098466  0.887902  0.864351 -2.083920
# 3  1.982731  0.142747  0.945775 -0.471427
# 4  0.794522  1.220279 -0.139830  2.066535
# 5 -0.322936  1.882360  0.516391 -0.614309
# 6  0.869309 -1.127183  0.691726 -0.644516
# 7  2.226430  0.906471  1.518588  0.756857
# 8 -1.647199 -1.569137 -0.508996 -0.295982
# 9 -0.071840 -0.267649 -0.425719 -0.937559

# %%
df.plot.bar()

# %%
df.plot(kind = 'bar')

# %%
df.plot.barh()

# %%
iris.plot.hist()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['sepal_length'].plot.hist() # X axis is range of data Y axis is freq of data

# %%
iris.plot(kind = 'hist')

# %%
iris.plot(kind = 'hist', stacked = False, bins = 100) #Stacked False means bring smaller graphs in front bins is width

# %%
iris.plot(kind = 'hist', stacked = True, bins = 50, orientation = 'horizontal')

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.1, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001DBAF808>,
# ...
#       dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length') # relation b/w two

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10))

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001F409B88>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000001F520208>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde() # Kernel Density Estimate

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)

# %%
x.plot(figsize=(10,5), x_compat = True)

# %%
df.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1ec1ea58>,
# ...
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-93-af09896ed1db> in <module>
# ----> 1 from descartes import PolygonPatch
#
# ModuleNotFoundError: No module named 'descartes'

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()

# %%
import geopandas as gpd

# %%
map_df
# Out:
#                       NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER  \
# 0     Kingston upon Thames  E09000021   3726.117       0.000         F
# 1                  Croydon  E09000008   8649.441       0.000         F
# 2                  Bromley  E09000006  15013.487       0.000         F
# 3                 Hounslow  E09000018   5658.541      60.755         F
# 4                   Ealing  E09000009   5554.428       0.000         F
# 5                 Havering  E09000016  11445.735     210.763         F
# 6               Hillingdon  E09000017  11570.063       0.000         F
# 7                   Harrow  E09000015   5046.330       0.000         F
# 8                    Brent  E09000005   4323.270       0.000         F
# 9                   Barnet  E09000003   8674.837       0.000         F
# 10                 Lambeth  E09000022   2724.940      43.927         T
# 11               Southwark  E09000028   2991.340     105.139         T
# ...
