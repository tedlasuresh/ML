# %%
# Pandas _ Practice

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
# chipotle Dataset
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
# read the above file
df = pd.read_csv(url, sep = '\t')

# %%
# Print top 5 records from the dataset
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# Print last 7 records from the dataset
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description item_price
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4616                                                NaN     $4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
# print total records and type of variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
# print total records and type of variables
df.shape[0]
# Out:
# 4622

# %%
# Return a tuple representing the dimensionality of the DataFrame.
df.shape
# Out:
# (4622, 5)

# %%
# Print name of all the columns
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#How is the dataset indexed?
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Which was the most ordered items? and How many times ordered?
a = df.groupby('item_name')
a = a.sum()
a
# Out:
#                                        order_id  quantity
# item_name
# 6 Pack Soft Drink                         52322        55
# Barbacoa Bowl                             53972        66
# Barbacoa Burrito                          74718        91
# Barbacoa Crispy Tacos                      5613        12
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Soft Tacos                       18725        25
# Bottled Water                            175944       211
# Bowl                                        472         4
# Burrito                                    1550         6
# Canned Soda                               76396       126
# Canned Soft Drink                        304753       351
# Carnitas Bowl                             62742        71
# Carnitas Burrito                          51652        60
# Carnitas Crispy Tacos                      5868         8
# Carnitas Salad                             1500         1
# ...

# %%
a = a.sort_values(['quantity'],ascending=False)
a
# Out:
#                                        order_id  quantity
# item_name
# Chicken Bowl                             713926       761
# Chicken Burrito                          497303       591
# Chips and Guacamole                      449959       506
# Steak Burrito                            328437       386
# Canned Soft Drink                        304753       351
# Chips                                    208004       230
# Steak Bowl                               193752       221
# Bottled Water                            175944       211
# Chips and Fresh Tomato Salsa             100419       130
# Canned Soda                               76396       126
# Chicken Salad Bowl                       117104       123
# Chicken Soft Tacos                        98395       120
# Side of Chips                             84769       110
# Veggie Burrito                            80962        97
# Barbacoa Burrito                          74718        91
# ...

# %%
# Print top 1 record 
a.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
b = df.groupby('choice_description').sum()
b
# Out:
#                                                     order_id  quantity
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...       214         1
# [Adobo-Marinated and Grilled Chicken, [Sour Cre...       279         1
# [Adobo-Marinated and Grilled Chicken]                    217         1
# [Adobo-Marinated and Grilled Steak, [Sour Cream...       279         1
# [Adobo-Marinated and Grilled Steak]                      217         1
# ...                                                      ...       ...
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      2576         2
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1215         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...        51         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...        51         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1299         1
#
# [1043 rows x 2 columns]

# %%
b = b.sort_values(['quantity'], ascending=False)
b.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
df.item_price.dtype
# Out:
# dtype('O')

# %%
# Turn the item price into a float
df.item_price = df.item_price.apply(lambda x: float(x[1:-1])) # Float is not indexable object

# %%
revenue = (df['quantity']* df['item_price']).sum()
revenue
# Out:
# 39237.02

# %%
print('Revenue was: $' + str(np.round(revenue,2)))
# Out:
# Revenue was: $39237.02

# %%
# print a data frame with only two columns item_name and item_price columns
type(df[['item_name','item_price']])
# Out:
# pandas.core.frame.DataFrame

# %%
# Delete the duplicates in item_name and quantity
filtered = df.drop_duplicates(['item_name','quantity'])
print(type(filtered))
filtered
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 3890      1559         2                  Carnitas Crispy Tacos
# 3973      1592         4                      Canned Soft Drink
# 4152      1660        10                          Bottled Water
# 4354      1738         2                       Steak Soft Tacos
# 4489      1786         4                    Chips and Guacamole
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
# Select only products with quantity is 1
one_product = filtered[filtered['quantity'] == 1]
one_product
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 21          11         1                       Barbacoa Burrito
# 27          14         1                       Carnitas Burrito
# ...

# %%
# select only the item_name and item_price columns
price_per_item = one_product[['item_name','item_price']]
price_per_item
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 5                              Chicken Bowl       10.98
# 6                             Side of Chips        1.69
# 7                             Steak Burrito       11.75
# 8                          Steak Soft Tacos        9.25
# 10                      Chips and Guacamole        4.45
# 11                     Chicken Crispy Tacos        8.75
# 12                       Chicken Soft Tacos        8.75
# 16                          Chicken Burrito        8.49
# 21                         Barbacoa Burrito        8.99
# 27                         Carnitas Burrito        8.99
# 28                              Canned Soda        1.09
# 33                            Carnitas Bowl        8.99
# ...

# %%
# sort the values from most expensive to less expensive
price_per_item.sort_values(['item_price'],ascending=False)
# Out:
#                                   item_name  item_price
# 606                        Steak Salad Bowl       11.89
# 1229                    Barbacoa Salad Bowl       11.89
# 1132                    Carnitas Salad Bowl       11.89
# 7                             Steak Burrito       11.75
# 168                   Barbacoa Crispy Tacos       11.75
# 39                            Barbacoa Bowl       11.75
# 738                       Veggie Soft Tacos       11.25
# 186                       Veggie Salad Bowl       11.25
# 62                              Veggie Bowl       11.25
# 57                           Veggie Burrito       11.25
# 250                           Chicken Salad       10.98
# 5                              Chicken Bowl       10.98
# 8                          Steak Soft Tacos        9.25
# 554                   Carnitas Crispy Tacos        9.25
# 237                     Carnitas Soft Tacos        9.25
# 56                      Barbacoa Soft Tacos        9.25
# ...

# %%
# What was the quantity of the most expensive item ordered?
result = df.sort_values(['item_price'],ascending=False).head(1)
result
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
result['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
# How many times were a Veggie Salad Bowl ordered?
df[df['item_name'] == "Veggie Salad Bowl"]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %%
df[df['item_name'] == "Veggie Salad Bowl"].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Drinks Dataset
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')

# %%
df.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# For each continent print the statistics for beer consumption.
df.groupby('continent').beer_servings.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0

# %%
# Which continent drinks more beer on average?
df.groupby('continent').beer_servings.mean() # .max()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# For each continent print the statistics for wine consumption.
df.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# Us Crime Rates Dataset
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'
crime = pd.read_csv(url)

crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#Convert the type of the column Year to datetime64
crime.Year = pd.to_datetime(crime.Year,format='%Y')

# %%
crime.Year.head() # Default values is 01 month 01 day
# Out:
# 0   1960-01-01
# 1   1961-01-01
# 2   1962-01-01
# 3   1963-01-01
# 4   1964-01-01
# Name: Year, dtype: datetime64[ns]

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
# Set the Year column as the index of the dataframe
crime = crime.set_index('Year',drop=True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
# Group the year by decades and sum the values

# Uses resample to sum each decade
crimes = crime.resample('10AS').sum()

# %%
# Uses resample to get the max value only for the "Population" column
population = crime['Population'].resample('10AS').max()

# Updating the "Population" column
crimes['Population'] = population


crimes
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   201385000   49295900   4134930   45160900  106180         236720
# 1970-01-01   220099000  100991600   9607930   91383800  192230         554570
# 1980-01-01   248239000  131123369  14074328  117048900  206439         865639
# 1990-01-01   272690813  136582146  17527048  119053499  211664         998827
# 2000-01-01   307006550  115012044  13968056  100944369  163068         922499
# 2010-01-01   318857056   50167967   6072017   44095950   72867         421059
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01  1633510             2158520  13321100       26547700
# 1970-01-01  4159020             4702120  28486000       53157800
# 1980-01-01  5383109             7619130  33073494       72040253
# 1990-01-01  5748930            10568963  26750015       77679366
# 2000-01-01  4230366             8652124  21565176       67970291
# ...

# %%
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
# Return the first 3 rows of the DataFrame df.
df = crime

# %%
df.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# ...

# %%
# Return the first 3 rows of the DataFrame df.
df.iloc[0:3]
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# 1962-01-01         366800

# %%
# Select just the 'Murder' and 'Robbery' columns from the DataFrame df and print five records
df.loc[:,['Murder','Robbery']].head(5)
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
# Select just the 'Murder' and 'Robbery' columns from the DataFrame df and print five records
df[['Murder','Robbery']].head(5)
# Out:
#             Murder  Robbery
# Year
# 1960-01-01    9110   107840
# 1961-01-01    8740   106670
# 1962-01-01    8530   110860
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390

# %%
# Select the data in rows [3, 4, 8] and in columns ['Murder', 'Robbery']
df.loc[df.index[[3,4,8]],['Murder','Robbery']]
# Out:
#             Murder  Robbery
# Year
# 1963-01-01    8640   116470
# 1964-01-01    9360   130390
# 1968-01-01   13800   262840

# %%
# Select only the rows where the number of murder is greater than 24,000
df[df['Murder'] > 24000]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1991-01-01   687730             1092740   3157200        8142200
# 1993-01-01   659870             1135610   2834800        7820900
#
#             Vehicle_Theft
# Year
# 1991-01-01        1661700
# 1993-01-01        1563100

# %%
# Select the rows the murder is between 20k and 24k (inclusive)
df[df['Murder'].between(20000,24000)]
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1974-01-01   211392000  10253400   974720   9278700   20710          55400
# 1975-01-01   213124000  11292400  1039710  10252700   20510          56090
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# 1986-01-01   240132887  13211869  1489169  11722700   20613          91459
# 1987-01-01   242282918  13508700  1483999  12024700   20096          91110
# 1988-01-01   245807000  13923100  1566220  12356900   20680          92490
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# ...

# %%
# Calculate the mean murder for each different year in df.
df.groupby('Year')['Murder'].mean()
# Out:
# Year
# 1960-01-01     9110
# 1961-01-01     8740
# 1962-01-01     8530
# 1963-01-01     8640
# 1964-01-01     9360
# 1965-01-01     9960
# 1966-01-01    11040
# 1967-01-01    12240
# 1968-01-01    13800
# 1969-01-01    14760
# 1970-01-01    16000
# 1971-01-01    17780
# 1972-01-01    18670
# 1973-01-01    19640
# 1974-01-01    20710
# 1975-01-01    20510
# 1976-01-01    18780
# 1977-01-01    19120
# 1978-01-01    19560
# 1979-01-01    21460
# 1980-01-01    23040
# 1981-01-01    22520
# 1982-01-01    21010
# 1983-01-01    19310
# 1984-01-01    18690
# 1985-01-01    18980
# 1986-01-01    20613
# 1987-01-01    20096
# 1988-01-01    20680
# 1989-01-01    21500
# 1990-01-01    23440
# 1991-01-01    24700
# 1992-01-01    23760
# 1993-01-01    24530
# 1994-01-01    23330
# 1995-01-01    21610
# 1996-01-01    19650
# 1997-01-01    18208
# 1998-01-01    16914
# 1999-01-01    15522
# 2000-01-01    15586
# 2001-01-01    16037
# 2002-01-01    16229
# 2003-01-01    16528
# 2004-01-01    16148
# ...

# %%
# Sort df first by the values in the 'Murder' in decending order,
# then by the value in the 'Violent' column in ascending order.
df.sort_values(['Murder','Violent'],ascending=[False,True])
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
# 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 1995-01-01   262755000  13862700  1798790  12063900   21610          97470
# 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# ...

# %%
# Motor Car Dataset
import pandas as pd
import numpy as np
url = 'https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/e38552ac3cb40a532941b09d7332b03d19409919/csv/datasets/mtcars.csv'
df = pd.read_csv(url)
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
# For each cyl type and each number of gears, find the mean mileage.
df.groupby(['cyl','gear'])['mpg'].mean()
# Out:
# cyl  gear
# 4    3       21.500
#      4       26.925
#      5       28.200
# 6    3       19.750
#      4       19.750
#      5       19.700
# 8    3       15.050
#      5       15.400
# Name: mpg, dtype: float64

# %%
# For each cyl type and each number of gears, find the mean mileage.
df.pivot_table(index='cyl', columns='gear', values='mpg', aggfunc='mean')
# Out:
# gear      3       4     5
# cyl
# 4     21.50  26.925  28.2
# 6     19.75  19.750  19.7
# 8     15.05     NaN  15.4

# %%
# Pandas Practise 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df2.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
df['Low'].isnull().count()
# Out:
# 4656

# %%
df['High'].isnull().count()
# Out:
# 4656

# %%
df['Comments'].isnull().count()
# Out:
# 4656

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['STATION', 'STATION_NAME', 'DATE', 'PRCP', 'SNWD', 'SNOW', 'TMAX',
#        'TMIN', 'WDFG', 'PGTM', 'WSFG', 'WT09', 'WT07', 'WT01', 'WT06', 'WT05',
#        'WT04', 'WT16', 'WT08', 'WT18', 'WT03'],
#       dtype='object')

# %%
# Renaming the column permanently in df Dataframe
df.rename(columns={"Indicator": "Indicator_updated"},inplace=True)
df.head()
# Out:
#                    Indicator_updated PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
# Renaming the column name permanently in df2 dataframe
df2.rename(columns={"STATION":"STATION_UPDATED"},inplace=True)
df2.head()
# Out:
#      STATION_UPDATED         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
# Change the names of multiple columns. In Df Dataframe
df.rename(columns={"PUBLISH STATES":"PUBLISH STATES_Updated","Year":"Year_Updated"},inplace=True)
df.head()
# Out:
#                    Indicator_updated PUBLISH STATES_Updated  Year_Updated  \
# 0   Life expectancy at birth (years)              Published          1990
# 1   Life expectancy at birth (years)              Published          2000
# 2  Life expectancy at age 60 (years)              Published          2012
# 3  Life expectancy at age 60 (years)              Published          2000
# 4   Life expectancy at birth (years)              Published          2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# ...

# %%
# Change the names of multiple columns. In Df2 Dataframe
df2.rename(columns={"STATION_NAME":"STATION_NAME_UPDATED","DATE":"DATE_UPDATED"},inplace=True)
df2.head()
# Out:
#      STATION_UPDATED STATION_NAME_UPDATED  DATE_UPDATED  PRCP  SNWD  SNOW  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM      19310101    46 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM      19310102   107 -9999 -9999
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM      19310103 -9999 -9999 -9999
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM      19310105    13 -9999 -9999
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM      19310106 -9999 -9999 -9999
#
#    TMAX  TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  \
# 0 -9999   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    50    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    28    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    39    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4     0   -22 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT08  WT18  WT03
# 0 -9999 -9999 -9999
# 1 -9999 -9999 -9999
# ...

# %%
# Arrange values of a particular column in ascending order.
df =df.sort_values(by=['Year_Updated'],ascending=True) # sort and Re assign it to df for changes
df.head()
# Out:
#                       Indicator_updated PUBLISH STATES_Updated  Year_Updated  \
# 0      Life expectancy at birth (years)              Published          1990
# 1270   Life expectancy at birth (years)              Published          1990
# 3193   Life expectancy at birth (years)              Published          1990
# 3194   Life expectancy at birth (years)              Published          1990
# 3197  Life expectancy at age 60 (years)              Published          1990
#
#      WHO region World Bank income group              Country         Sex  \
# 0        Europe             High-income              Andorra  Both sexes
# 1270     Europe             High-income              Germany        Male
# 3193     Europe     Lower-middle-income  Republic of Moldova        Male
# 3194     Europe     Lower-middle-income  Republic of Moldova  Both sexes
# 3197     Europe     Lower-middle-income  Republic of Moldova        Male
#
#       Display Value  Numeric  Low  High  Comments
# ...

# %%
# Arrange multiple column values in ascending order.
df.sort_values(by=['Indicator_updated','Country','Year_Updated','WHO region','PUBLISH STATES_Updated'],ascending=True)
df.head()
# Out:
#                       Indicator_updated PUBLISH STATES_Updated  Year_Updated  \
# 0      Life expectancy at birth (years)              Published          1990
# 1270   Life expectancy at birth (years)              Published          1990
# 3193   Life expectancy at birth (years)              Published          1990
# 3194   Life expectancy at birth (years)              Published          1990
# 3197  Life expectancy at age 60 (years)              Published          1990
#
#      WHO region World Bank income group              Country         Sex  \
# 0        Europe             High-income              Andorra  Both sexes
# 1270     Europe             High-income              Germany        Male
# 3193     Europe     Lower-middle-income  Republic of Moldova        Male
# 3194     Europe     Lower-middle-income  Republic of Moldova  Both sexes
# 3197     Europe     Lower-middle-income  Republic of Moldova        Male
#
#       Display Value  Numeric  Low  High  Comments
# ...

# %%
df.head(5)
# Out:
#                       Indicator_updated PUBLISH STATES_Updated  Year_Updated  \
# 0      Life expectancy at birth (years)              Published          1990
# 1270   Life expectancy at birth (years)              Published          1990
# 3193   Life expectancy at birth (years)              Published          1990
# 3194   Life expectancy at birth (years)              Published          1990
# 3197  Life expectancy at age 60 (years)              Published          1990
#
#      WHO region World Bank income group              Country         Sex  \
# 0        Europe             High-income              Andorra  Both sexes
# 1270     Europe             High-income              Germany        Male
# 3193     Europe     Lower-middle-income  Republic of Moldova        Male
# 3194     Europe     Lower-middle-income  Republic of Moldova  Both sexes
# 3197     Europe     Lower-middle-income  Republic of Moldova        Male
#
#       Display Value  Numeric  Low  High  Comments
# ...

# %%
df.columns
# Out:
# Index(['Indicator_updated', 'PUBLISH STATES_Updated', 'Year_Updated',
#        'WHO region', 'World Bank income group', 'Country', 'Sex',
#        'Display Value', 'Numeric', 'Low', 'High', 'Comments'],
#       dtype='object')

# %%
# Make country as the first column of the dataframe.
df  = df[['Country','Indicator_updated','PUBLISH STATES_Updated','Year_Updated','WHO region','World Bank income group','Sex','Display Value','Numeric','Low','High','Comments']]
df.head()
# Out:
#                   Country                  Indicator_updated  \
# 0                 Andorra   Life expectancy at birth (years)
# 1270              Germany   Life expectancy at birth (years)
# 3193  Republic of Moldova   Life expectancy at birth (years)
# 3194  Republic of Moldova   Life expectancy at birth (years)
# 3197  Republic of Moldova  Life expectancy at age 60 (years)
#
#      PUBLISH STATES_Updated  Year_Updated WHO region World Bank income group  \
# 0                 Published          1990     Europe             High-income
# 1270              Published          1990     Europe             High-income
# 3193              Published          1990     Europe     Lower-middle-income
# 3194              Published          1990     Europe     Lower-middle-income
# 3197              Published          1990     Europe     Lower-middle-income
#
#              Sex  Display Value  Numeric  Low  High  Comments
# 0     Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
df
# Out:
#                                Country  \
# 0                              Andorra
# 1270                           Germany
# 3193               Republic of Moldova
# 3194               Republic of Moldova
# 3197               Republic of Moldova
# ...                                ...
# 1316                             Italy
# 3141                        Cabo Verde
# 3139                          Cameroon
# 3156  Micronesia (Federated States of)
# 4655                          Zimbabwe
#
#                                     Indicator_updated PUBLISH STATES_Updated  \
# 0                    Life expectancy at birth (years)              Published
# 1270                 Life expectancy at birth (years)              Published
# 3193                 Life expectancy at birth (years)              Published
# 3194                 Life expectancy at birth (years)              Published
# 3197                Life expectancy at age 60 (years)              Published
# ...

# %%
# 9. Get the column array using a variable

result = df['Country'].to_numpy()
result
# Out:
# array(['Andorra', 'Germany', 'Republic of Moldova', ..., 'Cameroon',
#        'Micronesia (Federated States of)', 'Zimbabwe'], dtype=object)

# %%
# 10.Get the subset rows 11, 24, 37
df.loc[[11,24,37]]
# Out:
#               Country                  Indicator_updated  \
# 11            Austria   Life expectancy at birth (years)
# 24  Brunei Darussalam  Life expectancy at age 60 (years)
# 37             Cyprus  Life expectancy at age 60 (years)
#
#    PUBLISH STATES_Updated  Year_Updated       WHO region  \
# 11              Published          2012           Europe
# 24              Published          2012  Western Pacific
# 37              Published          2012           Europe
#
#    World Bank income group     Sex  Display Value  Numeric  Low  High  \
# 11             High-income  Female             83     83.0  NaN   NaN
# 24             High-income  Female             21     21.0  NaN   NaN
# 37             High-income  Female             26     26.0  NaN   NaN
#
#     Comments
# 11       NaN
# 24       NaN
# 37       NaN

# %%
# Get the subset rows excluding 5, 12, 23, and 56 
aaa = df[~df.index.isin([5,12,23,56])]
aaa.head()
# Out:
#                   Country                  Indicator_updated  \
# 0                 Andorra   Life expectancy at birth (years)
# 1270              Germany   Life expectancy at birth (years)
# 3193  Republic of Moldova   Life expectancy at birth (years)
# 3194  Republic of Moldova   Life expectancy at birth (years)
# 3197  Republic of Moldova  Life expectancy at age 60 (years)
#
#      PUBLISH STATES_Updated  Year_Updated WHO region World Bank income group  \
# 0                 Published          1990     Europe             High-income
# 1270              Published          1990     Europe             High-income
# 3193              Published          1990     Europe     Lower-middle-income
# 3194              Published          1990     Europe     Lower-middle-income
# 3197              Published          1990     Europe     Lower-middle-income
#
#              Sex  Display Value  Numeric  Low  High  Comments
# 0     Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
aaa = aaa.sort_index(axis=0,inplace=True)

# %%
aaa

# %%
# Loading the Users Dataset
df = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
df
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
# Loading the Sessions Dataset
df2 = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')

# %%
df2
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4
# 5          6  2012-10-23       4
# 6          7  2012-12-21       3
# 7          8  2013-05-22       4
# 8          9  2013-07-17       4
# 9         10  2016-01-11       4

# %%
# Loading the products Dataset
df3 = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')

# %%
df3
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
# Loading the Transactions Dataset
df4 = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
df4
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %%
df.head() # User Dataset
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
df2.head() # sessions Dataset
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
df3.head() # products Dataset
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
df4.head() # transactions Dataset
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
# Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)
pd.merge(df4, df, how='left',on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %%
# Which transactions have a UserID not in users?
# Need to solve - still pending

# %%
# Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)
pd.merge(df4,df,how='inner',on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %%
# Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)
pd.merge(df4,df,how='outer',on='UserID')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
# Determine which sessions occurred on the same day each user registered
# Need to solve - still pending

# %%
# Build a dataset with every possible (UserID, ProductID) pair (cross join)
# Need to solve - still pending

# %%
# Determine how much quantity of each product was purchased by each user
# Need to solve - still pending

# %%
# For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)
# Need to solve - still pending

# %%
# Join each user to his/her first occuring transaction in the transactions table
# Need to solve - still pending

# %% [markdown]
# # Data Cleaning - Pandas Assignment

# %%
# Dataframe for Data Cleaning Assignment

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',

'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
# Data Cleaning - Pandas Assignment Questions

# %%
# 1. Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 
# and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float 
# column).

# %%
# 2. The From_To column would be better as two separate columns! Split each string on the underscore delimiter _ to give a new 
# temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame.

# %%
# 3. Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame.Standardise the strings so that
# only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
# 4. Delete the From_To column from df and attach the temporary DataFrame from the previous questions.

# %%
# 5. In the RecentDelays column, the values have been entered into the DataFrame as a list.We would like each first value in its
# own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN.

# %%
# Expand the Series of lists into a DataFrame named delays, rename the columns delay_1, delay_2, etc. and replace the unwanted 
# RecentDelays column in df with delays.
